# %%
# Constant for 演習1.1~1.3
import re

def dec2int(s):
    return int(re.sub('\s', '', s))

class D1:
    p4 = dec2int('''730750818665451459523961714499640833062084344321''')
    g4 = 2
    g5 = dec2int('''630750818665451459 523961714499640833062084344321''')
    k4 = dec2int('''172350919665451459123451714499640833062234544321''')

class D3: 
    p1 = dec2int('''''')
    g1 = 2
    k1 = dec2int('''''')

class D4:
    p2 = dec2int('''''')
    g2 = dec2int('''''')
